# %%
# !pip install pywinauto
# Out:
# Collecting pywinauto
#   Downloading pywinauto-0.6.8-py2.py3-none-any.whl (362 kB)
# Requirement already satisfied: six in c:\users\nadeem\anaconda3\lib\site-packages (from pywinauto) (1.16.0)
# Requirement already satisfied: pywin32 in c:\users\nadeem\anaconda3\lib\site-packages (from pywinauto) (302)
# Requirement already satisfied: comtypes in c:\users\nadeem\anaconda3\lib\site-packages (from pywinauto) (1.1.10)
# Installing collected packages: pywinauto
# Successfully installed pywinauto-0.6.8

# %%
from pywinauto.application import Application
app = Application().start("notepad.exe")

app.UntitledNotepad.menu_select("Help->About Notepad")
app.AboutNotepad.OK.click()
app.UntitledNotepad.Edit.type_keys("pywinauto Works!", with_spaces = True)
# Out:
# <win32_controls.EditWrapper - 'pywinauto Works!', Edit, 1116790>

# %%
from pywinauto import Desktop, Application

Application().start('explorer.exe "C:\\Program Files"')

# connect to another process spawned by explorer.exe
# Note: make sure the script is running as Administrator!
app = Application(backend="uia").connect(path="explorer.exe", title="Program Files")

app.ProgramFiles.set_focus()
common_files = app.ProgramFiles.ItemsView.get_item('Common Files')
common_files.right_click_input()
app.ContextMenu.Properties.invoke()

# this dialog is open in another process (Desktop object doesn't rely on any process id)
Properties = Desktop(backend='uia').Common_Files_Properties
Properties.print_control_identifiers()
Properties.Cancel.click()
Properties.wait_not('visible') # make sure the dialog is closed
# Out:
# Control Identifiers:
#
# Dialog - 'Common Files Properties'    (L897, T403, R1393, B999)
# ['Common Files PropertiesDialog', 'Dialog', 'Common Files Properties']
# child_window(title="Common Files Properties", control_type="Window")
#    |
#    | Image - ''    (L932, T488, R974, B528)
#    | ['Image', 'Image0', 'Image1']
#    | child_window(auto_id="13057", control_type="Image")
#    |
#    | Image - ''    (L932, T538, R1356, B540)
#    | ['Image2']
#    | child_window(auto_id="13095", control_type="Image")
#    |
#    | Edit - 'Folder name:'    (L1030, T496, R1358, B524)
#    | ['Edit', 'Edit0', 'Edit1']
#    | child_window(title="Folder name:", auto_id="13156", control_type="Edit")
#    |
#    | Static - 'Type:'    (L932, T554, R1016, B572)
#    | ['Static', 'Type:Static', 'Type:', 'Static0', 'Static1']
#    | child_window(title="Type:", auto_id="13080", control_type="Text")
#    |
#    | Edit - 'Type:'    (L1030, T554, R1358, B582)
#    | ['Edit2', 'Type:Edit']
#    | child_window(title="Type:", auto_id="13059", control_type="Edit")
#    |
#    | Static - 'Location:'    (L932, T586, R1016, B604)
#    | ['Static2', 'Location:Static', 'Location:']
#    | child_window(title="Location:", auto_id="13089", control_type="Text")
#    |
#    | Edit - 'Location:'    (L1030, T586, R1358, B614)
#    | ['Location:Edit', 'Edit3']
#    | child_window(title="Location:", auto_id="13065", control_type="Edit")
#    |
#    | Static - 'Size:'    (L932, T618, R1016, B636)
#    | ['Static3', 'Size:', 'Size:Static']
#    | child_window(title="Size:", auto_id="13081", control_type="Text")
#    |
#    | Edit - 'Size:'    (L1030, T618, R1358, B646)
#    | ['Size:Edit', 'Edit4']
#    | child_window(title="Size:", auto_id="13064", control_type="Edit")
#    |
#    | Static - 'Size on disk:'    (L932, T650, R1016, B668)
#    | ['Static4', 'Size on disk:', 'Size on disk:Static']
#    | child_window(title="Size on disk:", auto_id="13107", control_type="Text")
#    |
#    | Edit - 'Size on disk:'    (L1030, T650, R1358, B678)
#    | ['Size on disk:Edit', 'Edit5']
#    | child_window(title="Size on disk:", auto_id="13106", control_type="Edit")
#    |
#    | Static - 'Contains:'    (L932, T682, R1016, B700)
#    | ['Static5', 'Contains:', 'Contains:Static', 'Contains:0', 'Contains:1']
#    | child_window(title="Contains:", auto_id="13088", control_type="Text")
#    |
#    | Edit - 'Contains:'    (L1030, T682, R1358, B710)
#    | ['Contains:Edit', 'Edit6']
#    | child_window(title="Contains:", auto_id="13087", control_type="Edit")
#    |
#    | Image - 'Contains:'    (L932, T714, R1356, B716)
#    | ['Image3', 'Contains:2', 'Contains:Image']
#    | child_window(title="Contains:", auto_id="13096", control_type="Image")
#    |
#    | Static - 'Created:'    (L932, T730, R1016, B748)
#    | ['Static6', 'Created:', 'Created:Static', 'Created:0', 'Created:1']
#    | child_window(title="Created:", auto_id="13092", control_type="Text")
#    |
#    | Edit - 'Created:'    (L1030, T730, R1358, B758)
#    | ['Created:Edit', 'Edit7']
#    | child_window(title="Created:", auto_id="13072", control_type="Edit")
#    |
#    | Image - 'Created:'    (L932, T762, R1356, B764)
#    | ['Image4', 'Created:Image', 'Created:2']
#    | child_window(title="Created:", auto_id="13097", control_type="Image")
#    |
#    | Static - 'Attributes:'    (L932, T778, R1016, B796)
#    | ['Static7', 'Attributes:', 'Attributes:Static']
#    | child_window(title="Attributes:", auto_id="13091", control_type="Text")
#    |
#    | CheckBox - 'Read-only (Only applies to files in folder)'    (L1030, T778, R1356, B798)
#    | ['Read-only (Only applies to files in folder)CheckBox', 'CheckBox', 'Read-only (Only applies to files in folder)', 'CheckBox0', 'CheckBox1']
#    | child_window(title="Read-only (Only applies to files in folder)", auto_id="13075", control_type="CheckBox")
#    |
#    | CheckBox - 'Hidden'    (L1030, T806, R1130, B826)
#    | ['CheckBox2', 'Hidden', 'HiddenCheckBox']
#    | child_window(title="Hidden", auto_id="13076", control_type="CheckBox")
#    |
#    | Button - 'Advanced...'    (L1216, T802, R1356, B830)
#    | ['Advanced...Button', 'Button', 'Advanced...', 'Button0', 'Button1']
#    | child_window(title="Advanced...", auto_id="13154", control_type="Button")
#    |
#    | Button - 'OK'    (L1060, T954, R1160, B982)
#    | ['OKButton', 'Button2', 'OK']
#    | child_window(title="OK", auto_id="1", control_type="Button")
#    |
#    | Button - 'Cancel'    (L1168, T954, R1268, B982)
#    | ['CancelButton', 'Button3', 'Cancel']
#    | child_window(title="Cancel", auto_id="2", control_type="Button")
#    |
#    | Button - 'Apply'    (L1276, T954, R1376, B982)
#    | ['Apply', 'ApplyButton', 'Button4']
#    | child_window(title="Apply", auto_id="12321", control_type="Button")
#    |
#    | TabControl - ''    (L914, T449, R1376, B946)
#    | ['TabControlSharing', 'TabControlCustomize', 'TabControlSecurity', 'TabControl', 'Type:TabControl', 'TabControlPrevious Versions']
#    | child_window(auto_id="12320", control_type="Tab")
#    |    |
#    |    | TabItem - 'General'    (L916, T451, R976, B472)
#    |    | ['General', 'TabItem', 'GeneralTabItem', 'TabItem0', 'TabItem1']
#    |    | child_window(title="General", control_type="TabItem")
#    |    |
#    |    | TabItem - 'Sharing'    (L976, T451, R1034, B472)
#    |    | ['Sharing', 'TabItem2', 'SharingTabItem']
#    |    | child_window(title="Sharing", control_type="TabItem")
#    |    |
#    |    | TabItem - 'Security'    (L1034, T451, R1094, B472)
#    |    | ['Security', 'SecurityTabItem', 'TabItem3']
#    |    | child_window(title="Security", control_type="TabItem")
#    |    |
#    |    | TabItem - 'Previous Versions'    (L1094, T451, R1215, B472)
#    |    | ['Previous VersionsTabItem', 'Previous Versions', 'TabItem4']
#    |    | child_window(title="Previous Versions", control_type="TabItem")
#    |    |
#    |    | TabItem - 'Customize'    (L1215, T451, R1289, B472)
#    |    | ['Customize', 'TabItem5', 'CustomizeTabItem']
#    |    | child_window(title="Customize", control_type="TabItem")
#    |
#    | TitleBar - ''    (L926, T406, R1384, B441)
#    | ['TitleBar']
#    |    |
#    |    | Menu - 'System'    (L906, T412, R934, B440)
#    |    | ['System', 'SystemMenu', 'Menu', 'System0', 'System1']
#    |    | child_window(title="System", auto_id="MenuBar", control_type="MenuBar")
#    |    |    |
#    |    |    | MenuItem - 'System'    (L906, T412, R934, B440)
#    |    |    | ['System2', 'MenuItem', 'SystemMenuItem']
#    |    |    | child_window(title="System", control_type="MenuItem")
#    |    |
#    |    | Button - 'Close'    (L1341, T404, R1385, B441)
#    |    | ['Close', 'CloseButton', 'Button5']
#    |    | child_window(title="Close", control_type="Button")
